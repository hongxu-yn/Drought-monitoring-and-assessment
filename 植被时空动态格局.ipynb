# %% [markdown]
# <a href="https://colab.research.google.com/github/hongxu-yn/Drought-monitoring-and-assessment/blob/main/%E6%A4%8D%E8%A2%AB%E6%97%B6%E7%A9%BA%E5%8A%A8%E6%80%81%E6%A0%BC%E5%B1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 初始化

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the target directory in MyDrive
drive_path = '/content/drive/MyDrive'
repo_url = 'https://github.com/hongxu-yn/Drought-monitoring-and-assessment.git'
repo_name = 'Drought-monitoring-and-assessment' # Extract repo name from URL

# Create the directory if it doesn't exist and change into it
import os
if not os.path.exists(drive_path):
    os.makedirs(drive_path)

# Change to the Google Drive directory
# %cd {drive_path}

# Check if the repository already exists to avoid errors
if not os.path.exists(os.path.join(drive_path, repo_name)):
    print(f"Cloning {repo_url} into {drive_path}")
    # !git clone {repo_url}
    print(f"Repository {repo_name} cloned successfully to {drive_path}")
else:
    print(f"Repository {repo_name} already exists in {drive_path}. Skipping clone.")
    print(f"You can update it by navigating to {os.path.join(drive_path, repo_name)} and running `!git pull`")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# Repository Drought-monitoring-and-assessment already exists in /content/drive/MyDrive. Skipping clone.
# You can update it by navigating to /content/drive/MyDrive/Drought-monitoring-and-assessment and running `!git pull`

# %%
# !apt-get install -y libgeos-dev
# !pip install cartopy geopandas
# !pip install rasterio rioxarray
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgeos-dev is already the newest version (3.12.1-1~jammy0).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Requirement already satisfied: cartopy in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (26.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (0.22.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.2.25)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from rioxarray) (26.0)
# Requirement already satisfied: xarray>=2026.2 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (2026.4.0)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (3.7.2)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray>=2026.2->rioxarray) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2026.2->rioxarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2026.2->rioxarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray>=2026.2->rioxarray) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray>=2026.2->rioxarray) (1.17.0)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import urllib.request

# 1. 下载中文字体 (SimHei) 到临时目录
font_url = "https://raw.githubusercontent.com/StellarCN/scp_zh/master/fonts/SimHei.ttf"
font_path = "/tmp/SimHei.ttf"
urllib.request.urlretrieve(font_url, font_path)

# 2. 将字体注册到 matplotlib
fm.fontManager.addfont(font_path)
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置默认字体为黑体
plt.rcParams['axes.unicode_minus'] = False     # 确保坐标轴上的负号(-)正常显示

# ==========================================
# 下面继续放您之前的画图代码：
# fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 12))
# ... [省略后续画图代码] ...

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist
import xarray as xr
import os
from pathlib import Path
project_dir= Path('/content/drive/MyDrive/Drought-monitoring-and-assessment')
path_station = project_dir/ 'data/站点编号及信息_选定_1969-2025.xlsx'
path_spei = project_dir / 'data/spei/SPEI_month_1969_2025.csv'


df_stations = pd.read_excel(path_station)
spei_df = pd.read_csv(path_spei)
spei_df = spei_df[spei_df['year'].between(2001, 2026)]
combined_df = pd.merge(spei_df, df_stations[['station', 'lat', 'lon']], on='station', how='inner')

# 4. 定义插值网格 (20-30N, 97-107E, Res: 0.05)
res = 0.05
lon_coords = np.arange(97.0, 107.0 + res, res)
lat_coords = np.arange(20.0, 30.0 + res, res)
grid_lon, grid_lat = np.meshgrid(lon_coords, lat_coords)
grid_points = np.column_stack((grid_lon.ravel(), grid_lat.ravel()))


def idw_func(x, y, z, target_pts, p=2):
    known_pts = np.column_stack((x, y))
    dist = cdist(target_pts, known_pts)
    dist = np.where(dist == 0, 1e-10, dist)
    weights = 1.0 / (dist ** p)
    return np.sum(weights * z, axis=1) / np.sum(weights, axis=1)

combined_df['time'] = pd.to_datetime(combined_df[['year', 'month']].assign(day=1))
time_steps = sorted(combined_df['time'].unique())
results = np.zeros((len(time_steps), len(lat_coords), len(lon_coords)))

print(f"开始插值，共 {len(time_steps)} 个月份...")

# 外层循环：支持未来批量处理多个尺度，例如 [1, 3, 6, 12]
for time_scale in range (1,13):
    field_name = f'SPEI{time_scale}_Month'
    output_nc = f'/content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI{time_scale:02d}_month_2001_2025.nc'

    results = np.full((len(time_steps), len(lat_coords), len(lon_coords)), np.nan)

    for i, t in enumerate(time_steps):
        curr_df = combined_df[combined_df['time'] == t].dropna(subset=[field_name, 'lat', 'lon'])

        if not curr_df.empty:
            z_grid = idw_func(curr_df['lon'].values, curr_df['lat'].values,
                              curr_df[field_name].values, grid_points)

            results[i, :, :] = z_grid.reshape(len(lat_coords), len(lon_coords))
        else:
            print(f"警告：{pd.to_datetime(t).strftime('%Y-%m')} 缺失全部站点数据，记为 NaN")

        if (i+1) % 120 == 0:
            print(f"进度 ({field_name}): 已完成 {pd.to_datetime(t).year} 年数据")

    ds = xr.Dataset(
        {"spei": (["time", "lat", "lon"], results)},
        coords={"time": time_steps, "lat": lat_coords, "lon": lon_coords}
    )

    ds.spei.attrs["units"] = "1"
    ds.spei.attrs["long_name"] = f"Standardized Precipitation Evapotranspiration Index ({time_scale}-month)"
    ds.spei.attrs["missing_value"] = np.nan

    ds.to_netcdf(output_nc)
    print(f"[{field_name}] 插值完成！文件已保存至: {output_nc}\n" + "-"*40)
# Out:
# 开始插值，共 288 个月份...
# 进度 (SPEI1_Month): 已完成 2010 年数据
# 进度 (SPEI1_Month): 已完成 2020 年数据
# [SPEI1_Month] 插值完成！文件已保存至: /content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI01_month_2001_2025.nc
# ----------------------------------------
# 进度 (SPEI2_Month): 已完成 2010 年数据
# 进度 (SPEI2_Month): 已完成 2020 年数据
# [SPEI2_Month] 插值完成！文件已保存至: /content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI02_month_2001_2025.nc
# ----------------------------------------
# 进度 (SPEI3_Month): 已完成 2010 年数据
# 进度 (SPEI3_Month): 已完成 2020 年数据
# [SPEI3_Month] 插值完成！文件已保存至: /content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI03_month_2001_2025.nc
# ----------------------------------------
# 进度 (SPEI4_Month): 已完成 2010 年数据
# 进度 (SPEI4_Month): 已完成 2020 年数据
# [SPEI4_Month] 插值完成！文件已保存至: /content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI04_month_2001_2025.nc
# ----------------------------------------
# 进度 (SPEI5_Month): 已完成 2010 年数据
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24085/2362007669.py in <cell line: 0>()
#      47
#      48         if not curr_df.empty:
# ---> 49             z_grid = idw_func(curr_df['lon'].values, curr_df['lat'].values,
#      50                               curr_df[field_name].values, grid_points)
#      51
#
# /tmp/ipykernel_24085/2362007669.py in idw_func(x, y, z, target_pts, p)
#      28     dist = np.where(dist == 0, 1e-10, dist)
#      29     weights = 1.0 / (dist ** p)
# ---> 30     return np.sum(weights * z, axis=1) / np.sum(weights, axis=1)
#      31
#      32 combined_df['time'] = pd.to_datetime(combined_df[['year', 'month']].assign(day=1))
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2248
#    2249
# -> 2250 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2251                     initial=None, where=None):
#    2252     return (a, out)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

df_stations = pd.read_excel(path_station)
spei_df = pd.read_csv(path_spei)
spei_df = spei_df[spei_df['year'].between(2001, 2026)]
combined_df = pd.merge(spei_df, df_stations[['station', 'lat', 'lon']], on='station', how='inner')


spei_cols = [col for col in spei_df.columns if 'SPEI' in col.upper()]

# 2. 按照 year 和 month 分组，计算所有站点的平均值
# 这样每个月就只剩下一个代表整个区域的平均 SPEI 值
regional_mean_df = spei_df.groupby(['year', 'month'])[spei_cols].mean().reset_index()

# 3. 创建一个标准的时间列 (Datetime) 用于 X 轴
regional_mean_df['Date'] = pd.to_datetime(regional_mean_df[['year', 'month']].assign(day=1))

# 4. 数据重塑 (Pivot / Transpose)
# 将 Date 设置为索引，只保留 SPEI 列，然后转置 (.T)
# 转置后：行(Index)变成了时间尺度，列(Columns)变成了时间
heatmap_data = regional_mean_df.set_index('Date')[spei_cols].T

# 为了让 Y 轴标签更好看，可以重命名一下索引 (例如去掉 '_Month')
heatmap_data.index = [idx.replace('_Month', '') for idx in heatmap_data.index]

# 5. 开始绘制热力图
# 设置画布大小：因为 2001-2025 有 300 个月，X 轴会比较长，宽度设大一点
plt.figure(figsize=(20, 6))

# 使用 seaborn 绘制热力图
# cmap='RdYlBu': 使用红-黄-蓝的渐变色 (发散型色带)
# center=0: 强制 0 值为中间色，这对于 SPEI 非常重要！
ax = sns.heatmap(
    heatmap_data,
    cmap='RdYlBu',      # 负值为红色(干旱)，正值为蓝色(湿润)
    center=0,           # 0 值为白色/浅黄色(正常)
    vmin=-2.5,          # 设置色标下限
    vmax=2.5,           # 设置色标上限
    cbar_kws={'label': 'SPEI (Regional Mean)'} # 图例标签
)

# 6. 优化 X 轴时间标签显示
# 默认情况下列名是 Timestamp，显示会很拥挤。我们将其格式化为 'YYYY-MM'
dates = heatmap_data.columns
# 每隔 12 个月 (1年) 显示一个刻度
tick_positions = range(0, len(dates), 12)
tick_labels = [dates[i].strftime('%Y') for i in tick_positions]

ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels, rotation=45, ha='right')

# 设置标题和轴标签
plt.title('Evolution of Drought: Multi-scale SPEI Heatmap', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Time Scale', fontsize=12)

# 调整布局并显示/保存
plt.tight_layout()
# plt.savefig('/content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei_heatmap.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from scipy.stats import linregress

# 定义需要绘制的时间尺度
time_scales = [1, 3, 6, 12]

# 创建一个 4 行 1 列的画布，共享 X 轴
fig, axes = plt.subplots(nrows=len(time_scales), ncols=1, figsize=(18, 12), sharex=True)

for i, scale in enumerate(time_scales):
    ax = axes[i]
    col_name = f'SPEI{scale}_Month'

    if col_name in regional_mean_df.columns:
        # 剔除可能存在的 NaN 值，确保回归计算不出错
        valid_data = regional_mean_df[['Date', col_name]].dropna()
        dates = valid_data['Date']
        values = valid_data[col_name].values

        # 1. 绘制柱状图 (负红正蓝)
        colors = ['#d73027' if val < 0 else '#4575b4' for val in values]
        ax.bar(dates, values, width=25, color=colors, align='center', alpha=0.8)
        ax.axhline(0, color='black', linewidth=1, linestyle='-')

        # 2. 计算线性趋势 (Linear Regression)
        # 构造一个 0, 1, 2... 的整数序列代表逐月时间步长
        x_months = np.arange(len(values))
        slope, intercept, r_value, p_value, std_err = linregress(x_months, values)

        # 计算拟合的 Y 值并绘制虚线趋势线
        trend_line = intercept + slope * x_months
        ax.plot(dates, trend_line, color='black', linestyle='--', linewidth=2.5, zorder=5)

        # 3. 计算年代际变化率与显著性标注
        # slope 是每月的变化率，乘以 120 得到每 10 年的变化率 (/10a)
        # 如果您只想要年际变化率，将其改为 slope * 12，单位写为 /a 即可
        rate_per_decade = slope * 120

        # 根据 p 值确定显著性星号标注
        if p_value < 0.01:
            sig = '**'
        elif p_value < 0.05:
            sig = '*'
        else:
            sig = '' # 不显著

        # 格式化显示的文本信息
        trend_text = f'Trend: {rate_per_decade:.3f} / 10a {sig}'

        # 将文本框放置在子图的左上角
        ax.text(0.01, 0.88, trend_text, transform=ax.transAxes, fontsize=13, fontweight='bold',
                bbox=dict(facecolor='white', alpha=0.8, edgecolor='none', boxstyle='round,pad=0.3'))

        # 设置 Y 轴
        ax.set_ylabel(f'SPEI-{scale}', fontsize=14, fontweight='bold')
        ax.set_ylim(-3, 3)
        ax.grid(True, axis='y', linestyle=':', alpha=0.6)

# 设置 X 轴的格式
axes[-1].xaxis.set_major_locator(mdates.YearLocator(2)) # 每 2 年显示一个刻度，防止过于拥挤
axes[-1].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
axes[-1].set_xlabel('Year', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)

# 总体标题
plt.suptitle('Temporal Evolution and Trend of Regional Mean SPEI (2001-2025)', fontsize=18, y=0.98)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.94)

# 保存高分辨率图片，适合期刊发表
# plt.savefig('SPEI_Trend_MultiScale.jpg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress

# 1. 提取代表四个季节的月份，并映射标签
season_mapping = {2: '冬季', 5: '春季', 8: '夏季', 11: '秋季'}

# 从总数据中过滤出这四个月份的数据
seasonal_df = spei_df[spei_df['month'].isin(season_mapping.keys())].copy()

# 新增一列 'Season' 作为季节标识
seasonal_df['Season'] = seasonal_df['month'].map(season_mapping)

# 2. 定义一个专门针对单个站点、单个季节时间序列的计算函数
def calc_station_metrics(group):
    # 按年份排序，确保时间序列从早到晚，并剔除缺测值
    group = group.sort_values('year').dropna(subset=['SPEI3_Month'])

    # 如果该站点某季节的有效数据太少（例如少于 5 年），则放弃趋势计算
    if len(group) < 5:
        return pd.Series({'多年平均': np.nan, '变化率_10a': np.nan, 'P值': np.nan, '显著性': ''})

    y = group['SPEI3_Month'].values
    x = np.arange(len(y)) # 生成 0, 1, 2... 代表连续的年份步长

    # 计算多年平均值
    mean_val = np.mean(y)

    # 执行一元线性回归
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # 这里的 slope 单位是 "SPEI / 年"。乘以 10 转换为 "SPEI / 10年"
    trend_10a = slope * 10

    # 确定显著性水平标签
    if p_value < 0.01:
        sig = '**'  # 极显著
    elif p_value < 0.05:
        sig = '*'   # 显著
    else:
        sig = ''    # 不显著

    return pd.Series({
        '多年平均': round(mean_val, 4),
        '变化率_10a': round(trend_10a, 4),
        'P值': round(p_value, 4),
        '显著性': sig
    })

# 3. 分组计算：按站点和季节分组，应用上述函数
print("正在计算各站点的季节统计量...")
station_seasonal_stats = seasonal_df.groupby(['station', 'Season']).apply(calc_station_metrics).reset_index()

# 4. 数据透视 (Pivot)：将长表转换为宽表，让结果更符合论文表格的要求
# 行是站点，列是：春季_多年平均, 春季_变化率_10a...
final_table = station_seasonal_stats.pivot(index='station', columns='Season')

# 扁平化多级表头并重命名
final_table.columns = [f"{col[1]}_{col[0]}" for col in final_table.columns]
final_table = final_table.reset_index()

# 为了符合四季顺序，可以对列进行重新排序
cols_order = ['station']
for season in ['春季', '夏季', '秋季', '冬季']:
    cols_order.extend([f"{season}_多年平均", f"{season}_变化率_10a", f"{season}_P值", f"{season}_显著性"])

# 只保留实际存在的列（防止数据缺失导致报错）
cols_order = [col for col in cols_order if col in final_table.columns]
final_table = final_table[cols_order]

print("计算完成！前 5 个站点的结果如下：")
print(final_table.head())

# 5. 保存结果到 Excel，方便后续在 ArcGIS 中做空间分布图
# output_excel = project_dir / 'data/SPEI3_Seasonal_Trend_Stations.xlsx'
# final_table.to_excel(output_excel, index=False)
# print(f"结果已保存至：{output_excel}")
# Out:
# 正在计算各站点的季节统计量...
# 计算完成！前 5 个站点的结果如下：
#    station  春季_多年平均  春季_变化率_10a   春季_P值 春季_显著性  夏季_多年平均  夏季_变化率_10a   夏季_P值  \
# 0    56444  -0.0609     -0.2543  0.4750         -0.0059     -0.0787  0.7676
# 1    56483  -0.1157      0.3137  0.3321          0.0353     -0.2029  0.5530
# 2    56489  -0.0633     -0.0595  0.8512          0.1160     -0.2675  0.3771
# 3    56497  -0.1305      0.2363  0.4182         -0.0581     -0.5628  0.0586
# 4    56533  -0.2265     -0.0836  0.7976         -0.0182      0.0572  0.8520
#
#   夏季_显著性  秋季_多年平均  秋季_变化率_10a   秋季_P值 秋季_显著性  冬季_多年平均  冬季_变化率_10a   冬季_P值  \
# 0         -0.3016     -0.2624  0.3179         -0.1346      0.3032  0.3326
# 1          0.2503      0.2526  0.3482         -0.1038     -0.1947  0.5966
# 2         -0.1007     -0.2221  0.4722         -0.3803     -0.7918  0.0043
# 3          0.1438     -0.1022  0.7419         -0.2143     -0.2030  0.4816
# 4         -0.3423      0.0130  0.9659         -0.1439     -0.1077  0.7391
#
#   冬季_显著性
# 0
# 1
# 2     **
# 3
# 4
# /tmp/ipykernel_24085/3520030125.py:52: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   station_seasonal_stats = seasonal_df.groupby(['station', 'Season']).apply(calc_station_metrics).reset_index()

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import geopandas as gpd
from scipy.spatial.distance import cdist
from pathlib import Path
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# ==========================================
# 0. 环境准备 (解决中文字体和 Shapefile)
# ==========================================

# 1. 解决中文字体问题 (针对 Colab/Linux 环境)
# 尝试找到一个已安装的 CJK 字体，例如 Noto Sans CJK
# 如果在其他 OS 上运行，请修改为对应的中文字体名称
plt.rcParams['font.sans-serif'] = ['SimHei', 'Noto Sans CJK JP', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False # 解决负号显示问题

# 2. 读取云南省界 Shapefile (用于裁剪显示)
gis_dir = Path("/content/drive/MyDrive/gis")
yn_gdf_path = gis_dir / 'boua_s.shp'
# 检查文件是否存在
if not yn_gdf_path.exists():
    raise FileNotFoundError(f"找不到 Shapefile 文件：{yn_gdf_path}，请检查路径。")
yn_boundary = gpd.read_file(yn_gdf_path)

# 获取 shapefile 的边界框 [xmin, ymin, xmax, ymax]，用于设置地图显示范围
bounds = yn_boundary.total_bounds

# ==========================================
# 1-4. 数据准备与合并 (假设 df_stations 和 final_table 已存在)
# ==========================================
# 注意：这部分代码假设 final_table 和 df_stations 已在您之前的会话中生成
# 这里仅重复关键的合并步骤，确保 interp_df 可用
# 您需要确认 final_table 包含了所有 4 个季节的 多年平均 和 变化率 列

interp_df = pd.merge(final_table, df_stations[['station', 'lat', 'lon']], on='station', how='inner')

# ==========================================
# 2. 定义目标网格和 IDW 函数
# ==========================================
res = 0.05
lon_coords = np.arange(97.0, 107.0 + res, res)
lat_coords = np.arange(20.0, 30.0 + res, res)
grid_lon, grid_lat = np.meshgrid(lon_coords, lat_coords)
grid_points = np.column_stack((grid_lon.ravel(), grid_lat.ravel()))

def idw_func(x, y, z, target_pts, p=2):
    known_pts = np.column_stack((x, y))
    dist = cdist(target_pts, known_pts)
    dist = np.where(dist == 0, 1e-10, dist) # 避免除零
    weights = 1.0 / (dist ** p)
    return np.sum(weights * z, axis=1) / np.sum(weights, axis=1)

# ==========================================
# 3. 循环四季与变量进行插值
# ==========================================
seasons = ['春季', '夏季', '秋季', '冬季']
variables = ['多年平均', '变化率_10a']

# 准备一个字典来存储所有生成的 numpy 数组
grid_results = {}

print("开始执行季节属性的空间插值...")
for season in seasons:
    for var in variables:
        col_name = f"{season}_{var}"

        # 确保该列存在于数据框中
        if col_name in interp_df.columns:
            # 剔除存在 NaN 的异常站点
            valid_df = interp_df.dropna(subset=[col_name, 'lat', 'lon'])

            if not valid_df.empty:
                # 执行 IDW 插值
                z_grid = idw_func(
                    valid_df['lon'].values,
                    valid_df['lat'].values,
                    valid_df[col_name].values,
                    grid_points
                )

                # 重塑为二维并存入字典 (注意：键名为变量名)
                grid_results[col_name] = z_grid.reshape(len(lat_coords), len(lon_coords))
                print(f"[{col_name}] 插值完成。")

# ==========================================
# 4. 构建多变量 xarray.Dataset 并保存
# ==========================================
# 动态构建 data_vars 字典
data_vars = {
    var_name: (["lat", "lon"], grid_data)
    for var_name, grid_data in grid_results.items()
}

ds_seasonal = xr.Dataset(
    data_vars,
    coords={"lat": lat_coords, "lon": lon_coords}
)

# 保存为 nc 文件
output_nc = '/content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI3_Seasonal_Spatial_Trend.nc'
ds_seasonal.to_netcdf(output_nc)
print(f"\n全部栅格数据已成功保存至：{output_nc}")


# ==========================================
# 5. 精细可视化：四季空间分布 (Cartopy 投影)
# ==========================================

# 设置一个 2 行 4 列的画布，使用 PlateCarree 投影
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(22, 12), subplot_kw={'projection': ccrs.PlateCarree()})

seasons = ['春季', '夏季', '秋季', '冬季']
variables = ['多年平均', '变化率_10a']
var_titles_en = {'多年平均': 'Long-term Mean', '变化率_10a': 'Interannual Trend Rate (/10a)'}

for i, var in enumerate(variables):
    for j, season in enumerate(seasons):
        ax = axes[i, j]
        var_key = f"{season}_{var}"

        if var_key in ds_seasonal:
            data_to_plot = ds_seasonal[var_key]

            # 设置地图装饰 (加载 cartopy 特色边界)
            ax.add_feature(cfeature.COASTLINE, linewidth=0.5)
            ax.add_feature(cfeature.BORDERS, linestyle='-', linewidth=0.5)

            # **应用 Shapefile 裁剪显示**：绘制 shapefile 的边界线
            ax.add_geometries(yn_boundary.geometry, crs=ccrs.PlateCarree(), facecolor='none', edgecolor='black', linewidth=0.75, alpha=0.9, zorder=4)

            # 根据 shapefile 边界框设置地图显示范围
            ax.set_extent([bounds[0], bounds[2], bounds[1], bounds[3]], crs=ccrs.PlateCarree())

            # 根据变量类型设置不同的色标范围
            if var == '多年平均':
                # 多年平均值的单位通常是标准化指数 (SPEI)，vmin/vmax 设为 [-2, 2]
                vmin, vmax = -2, 2
                cmap = 'RdYlBu'
            else:
                # 变化率的单位是 SPEI / 10a，vmin/vmax 设为 [-0.8, 0.8]
                vmin, vmax = -0.8, 0.8
                cmap = 'RdYlBu'

            # 使用 contourf 绘制平滑的等值线填充图
            cf = ax.contourf(
                ds_seasonal['lon'], ds_seasonal['lat'], data_to_plot,
                levels=np.linspace(vmin, vmax, 21), # 21个渐变层级
                cmap=cmap, extend='both', transform=ccrs.PlateCarree()
            )

            # 将原始观测站点作为散点叠加在图上
            ax.scatter(interp_df['lon'], interp_df['lat'], c='black', s=10, marker='x', alpha=0.5, transform=ccrs.PlateCarree())

            # 设置子图标题 (英文，适合发表 SCI)
            ax.set_title(f'{season} {var_titles_en[var]}', fontsize=12, fontweight='bold')

            # 添加经纬度网格线和标签
            gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, linestyle='--', alpha=0.3)
            gl.top_labels = False # 隐藏顶部标签
            gl.right_labels = False # 隐藏右侧标签

# ==========================================
# 6. 添加双 Colorbar
# ==========================================

# 1. 为第一行 (多年平均) 添加 Colorbar
# [left, bottom, width, height] 在图表底部添加一个水平色标
cbar_ax1 = fig.add_axes([0.15, 0.52, 0.7, 0.015])
cbar1 = fig.colorbar(cf, cax=cbar_ax1, orientation='horizontal')
cbar1.set_label('SPEI Long-term Mean (Unitless)', fontsize=13, fontweight='bold')

# 2. 为第二行 (变化率) 添加 Colorbar
# 注意：cf 变量保存了最后一次 contourf 的对象，它对应第二行的色标设置
cbar_ax2 = fig.add_axes([0.15, 0.05, 0.7, 0.015])
cbar2 = fig.colorbar(cf, cax=cbar_ax2, orientation='horizontal')
cbar2.set_label('Decadal Trend Rate (SPEI / 10a)', fontsize=13, fontweight='bold')

# 调整子图布局
plt.subplots_adjust(top=0.95, bottom=0.1, hspace=0.3, wspace=0.2)

# 保存高分辨率图片，适合期刊发表
# output_png = '/content/drive/MyDrive/Drought-monitoring-and-assessment/data/Seasonal_Mean_Trend_Spatial.png'
# plt.savefig(output_png, dpi=300, bbox_inches='tight')
# print(f"高分辨率空间分布图已保存至：{output_png}")

plt.show()
# Out:
# 开始执行季节属性的空间插值...
# [春季_多年平均] 插值完成。
# [春季_变化率_10a] 插值完成。
# [夏季_多年平均] 插值完成。
# [夏季_变化率_10a] 插值完成。
# [秋季_多年平均] 插值完成。
# [秋季_变化率_10a] 插值完成。
# [冬季_多年平均] 插值完成。
# [冬季_变化率_10a] 插值完成。
#
# 全部栅格数据已成功保存至：/content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI3_Seasonal_Spatial_Trend.nc
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.12/dist-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 26149 (\N{CJK UNIFIED IDEOGRAPH-6625}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 22799 (\N{CJK UNIFIED IDEOGRAPH-590F}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 31179 (\N{CJK UNIFIED IDEOGRAPH-79CB}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:512: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/cartopy/mpl/geoaxes.py:509: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)

# %%
time_steps
# Out:
# [Timestamp('2001-01-01 00:00:00'),
#  Timestamp('2001-02-01 00:00:00'),
#  Timestamp('2001-03-01 00:00:00'),
#  Timestamp('2001-04-01 00:00:00'),
#  Timestamp('2001-05-01 00:00:00'),
#  Timestamp('2001-06-01 00:00:00'),
#  Timestamp('2001-07-01 00:00:00'),
#  Timestamp('2001-08-01 00:00:00'),
#  Timestamp('2001-09-01 00:00:00'),
#  Timestamp('2001-10-01 00:00:00'),
#  Timestamp('2001-11-01 00:00:00'),
#  Timestamp('2001-12-01 00:00:00'),
#  Timestamp('2002-01-01 00:00:00'),
#  Timestamp('2002-02-01 00:00:00'),
#  Timestamp('2002-03-01 00:00:00'),
#  Timestamp('2002-04-01 00:00:00'),
#  Timestamp('2002-05-01 00:00:00'),
#  Timestamp('2002-06-01 00:00:00'),
#  Timestamp('2002-07-01 00:00:00'),
#  Timestamp('2002-08-01 00:00:00'),
#  Timestamp('2002-09-01 00:00:00'),
#  Timestamp('2002-10-01 00:00:00'),
#  Timestamp('2002-11-01 00:00:00'),
#  Timestamp('2002-12-01 00:00:00'),
#  Timestamp('2003-01-01 00:00:00'),
#  Timestamp('2003-02-01 00:00:00'),
#  Timestamp('2003-03-01 00:00:00'),
#  Timestamp('2003-04-01 00:00:00'),
#  Timestamp('2003-05-01 00:00:00'),
#  Timestamp('2003-06-01 00:00:00'),
#  Timestamp('2003-07-01 00:00:00'),
#  Timestamp('2003-08-01 00:00:00'),
#  Timestamp('2003-09-01 00:00:00'),
#  Timestamp('2003-10-01 00:00:00'),
#  Timestamp('2003-11-01 00:00:00'),
#  Timestamp('2003-12-01 00:00:00'),
#  Timestamp('2004-01-01 00:00:00'),
#  Timestamp('2004-02-01 00:00:00'),
#  Timestamp('2004-03-01 00:00:00'),
#  Timestamp('2004-04-01 00:00:00'),
#  Timestamp('2004-05-01 00:00:00'),
#  Timestamp('2004-06-01 00:00:00'),
#  Timestamp('2004-07-01 00:00:00'),
#  Timestamp('2004-08-01 00:00:00'),
#  Timestamp('2004-09-01 00:00:00'),
#  Timestamp('2004-10-01 00:00:00'),
#  Timestamp('2004-11-01 00:00:00'),
#  Timestamp('2004-12-01 00:00:00'),
#  Timestamp('2005-01-01 00:00:00'),
#  Timestamp('2005-02-01 00:00:00'),
#  Timestamp('2005-03-01 00:00:00'),
#  Timestamp('2005-04-01 00:00:00'),
# 31               31          31  2001      1    -0.376338    -0.747831
# 32               32          32  2002      1     0.887180     0.161631
# 33               33          33  2003      1    -0.341086    -0.163191
# 34               34          34  2004      1     1.051257     1.133410
# 35               35          35  2005      1    -0.031626    -0.136038
# ...             ...         ...   ...    ...          ...          ...
# 75895           655          50  2020     12    -0.141588    -1.679344
# 75896           656          51  2021     12     1.672609     1.330012
# 75897           657          52  2022     12     0.937283    -0.911125
# 75898           658          53  2023     12    -0.666248    -0.273599
# 75899           659          54  2024     12     0.095230    -0.742250
#
#        SPEI3_Month  SPEI4_Month  SPEI5_Month  SPEI6_Month  SPEI7_Month  \
# 31        0.059207     0.286271     0.440154     1.009083     0.776898
# 32       -0.197723     0.409644    -0.431191    -0.627915    -0.521177
# 33        0.670653     0.383127     0.497483     1.359429     2.046228
# 34        0.128145     0.170065     0.357890    -0.439400    -0.622882
# 35       -0.651910     0.173068    -0.296395    -1.127608    -0.869755
# ...            ...          ...          ...          ...          ...
# 75895    -0.613371     0.011419    -0.306967    -0.713006    -0.696184
# 75896     2.088099     1.463900     1.227948     1.144217     0.855730
# 75897    -0.312200     0.615337    -0.258362    -1.378686    -1.897734
# 75898    -0.670219    -1.184921     0.373658     0.147836    -0.124735
# 75899    -0.742572     1.220018     1.488382     0.965418     1.080032
#
#        SPEI8_Month  SPEI9_Month  SPEI10_Month  SPEI11_Month  SPEI12_Month  \
# 31        1.017988     1.280277      1.738648      1.536258      1.509285
# 32       -0.524139    -0.374422     -0.294212     -0.370434     -0.454509
# 33        1.822412     2.143857      1.853399      1.865275      1.759885
# 34       -0.365465    -0.557946     -0.686010     -0.941888     -0.895777
# 35       -0.640133     0.168921      0.127712      0.473552      0.415231
# ...            ...          ...           ...           ...           ...
# 75895    -0.782907    -0.598369     -0.422352     -0.473158     -0.530611
# 75896     0.295235     0.233676      0.023020      0.342534      0.291807
# 75897    -0.039733    -0.058025     -0.113373     -0.034178      0.151279
# 75898    -0.791037    -1.100849     -1.103504     -1.159215     -1.232387
# 75899     1.730191     1.545968      1.526486      1.416821      1.444282
#
#        station
# 31       56444
# 32       56444
# 33       56444
# 34       56444
# 35       56444
# ...        ...
# 75895    59007
# 75896    59007
# 75897    59007
# 75898    59007
# 75899    59007
#
# [33120 rows x 17 columns]

# %%
spei_df = spei_df[spei_df['year'].between(2001, 2025)]

# （可选）如果您想确认过滤是否成功，可以打印一下年份的唯一值
print("当前数据包含的年份：", sorted(spei_df['year'].unique()))
# Out:
# 当前数据包含的年份： [np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]

# %%
file_path = '/content/drive/MyDrive/Drought-monitoring-and-assessment/data/spei/SPEI_month_1969_2025.csv'
spei_df = pd.read_csv(file_path)
spei_df
# Out:
#        Unnamed: 0.1  Unnamed: 0  year  month  SPEI1_Month  SPEI2_Month  \
# 0                 0           0  1970      1     0.586047     0.290327
# 1                 1           1  1971      1     0.086309    -0.513946
# 2                 2           2  1972      1     0.395749     0.462702
# 3                 3           3  1973      1     0.626074     0.306521
# 4                 4           4  1974      1     0.327151     1.060036
# ...             ...         ...   ...    ...          ...          ...
# 75895           655          50  2020     12    -0.141588    -1.679344
# 75896           656          51  2021     12     1.672609     1.330012
# 75897           657          52  2022     12     0.937283    -0.911125
# 75898           658          53  2023     12    -0.666248    -0.273599
# 75899           659          54  2024     12     0.095230    -0.742250
#
#        SPEI3_Month  SPEI4_Month  SPEI5_Month  SPEI6_Month  SPEI7_Month  \
# 0         0.217796    -0.391929    -0.600458    -0.774367    -1.015283
# 1        -0.302477     1.168069     0.778865     0.532137     0.577783
# 2         1.229282     0.757013    -0.269353    -0.598058    -0.358511
# 3        -0.424853    -1.205340    -1.095086    -1.400175    -0.760676
# 4         1.473143     0.765227     0.136136     0.404166     0.712926
# ...            ...          ...          ...          ...          ...
# 75895    -0.613371     0.011419    -0.306967    -0.713006    -0.696184
# 75896     2.088099     1.463900     1.227948     1.144217     0.855730
# 75897    -0.312200     0.615337    -0.258362    -1.378686    -1.897734
# 75898    -0.670219    -1.184921     0.373658     0.147836    -0.124735
# 75899    -0.742572     1.220018     1.488382     0.965418     1.080032
#
#        SPEI8_Month  SPEI9_Month  SPEI10_Month  SPEI11_Month  SPEI12_Month  \
# 0        -0.770049    -0.889316     -0.889629     -1.090747     -1.173127
# 1         0.298646     0.698770      0.930900      1.255219      1.316218
# 2        -0.144341     0.173409     -0.351202     -0.663759     -0.688658
# 3        -1.106323    -1.133722     -0.478127     -0.599384     -0.548675
# 4         1.234130     0.954576      1.283286      1.144741      1.325142
# ...            ...          ...           ...           ...           ...
# 75895    -0.782907    -0.598369     -0.422352     -0.473158     -0.530611
# 75896     0.295235     0.233676      0.023020      0.342534      0.291807
# 75897    -0.039733    -0.058025     -0.113373     -0.034178      0.151279
# 75898    -0.791037    -1.100849     -1.103504     -1.159215     -1.232387
# 75899     1.730191     1.545968      1.526486      1.416821      1.444282
#
#        station
# 0        56444
# 1        56444
# 2        56444
# 3        56444
# 4        56444
# ...        ...
# 75895    59007
# 75896    59007
# 75897    59007
# 75898    59007
# 75899    59007
#
# [75900 rows x 17 columns]

# %%
# -*- coding: utf-8 -*-
#arcpy 批量空间插值
import copy
import datetime as datetime0
import datetime
import arcpy
from arcpy.sa import *
import os,sys

arcpy.CheckOutExtension("Spatial")
arcpy.env.overwriteOutput = True

arcpy.env.workspace=r'E:\workspace'
mask_shp=r'E:\gis\boua_s.shp'
arcpy.env.extent =mask_shp

startyear,endyear=1982,2022

#IDW空间插值

power = 2
workpath=r'E:\drought'
time_scale='month'

# %%
#IDW空间插值
print('IDW',datetime0.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
cellSize = 0.01
if cellSize == 0.01: gridpath='1km'
if cellSize ==0.05: gridpath='5km'

for dataname in ['clmSPEI']:
    if dataname=='clmSPEI': datapath='SPEI_TH'
    if dataname=='SPEI':datapath='SPEI_PM'

    spei_shp_path=os.path.join(workpath,'data','SPEI','SPEI',datapath,'month_shp')

    spei_grid_path=os.path.join(workpath,'step01_XY',gridpath)
    if not os.path.exists(spei_grid_path):  os.makedirs(spei_grid_path)
    spei_grid_path=os.path.join(workpath,'step01_XY',gridpath,dataname)
    if not os.path.exists(spei_grid_path):  os.makedirs(spei_grid_path)

    print('CELLSIZE IS：'+str(cellSize)+'输入出数据：'+spei_shp_path+'输出数据：'+spei_grid_path)

    timescales=list(range(11,13))
    for i in timescales:#时间尺度
        sel_d=dataname+str(i)
        fn = os.path.join(spei_shp_path,
                                sel_d+'_Month_'+str(startyear)+'_'+str(endyear)+'.shp')

        outpath=os.path.join(spei_grid_path,sel_d)
        if not os.path.exists(outpath):  os.makedirs(outpath)
        outpath=os.path.join(outpath,'month')
        if not os.path.exists(outpath):  os.makedirs(outpath)

        print('Time Scale'+str(i)+'  '+outpath)
        if not os.path.exists(outpath):  os.makedirs(outpath)
        for iy in range(startyear,endyear+1):
            #print('process year of:'+str(iy))
            for im in range(1,13):
                zField='S'+str(iy*100+im)
                outfn=os.path.join(outpath,
                                   sel_d+'_month_'+str(iy)+'_'+'{:02d}'.format(im)+'.tif')

                outIDW = Idw(fn, zField, cellSize, 2,  RadiusVariable(60, 10))
                outIDW.save(outfn)
                print(outfn+' is done!',datetime0.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('work is done!',datetime0.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# ('IDW', '2023-10-01 12:55:06')
# CELLSIZE IS：0.01输入出数据：E:\drought\data\SPEI\SPEI\SPEI_TH\month_shp输出数据：E:\drought\step01_XY\1km\clmSPEI
# Time Scale11  E:\drought\step01_XY\1km\clmSPEI\clmSPEI11\month
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_01.tif is done!', '2023-10-01 12:55:10')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_02.tif is done!', '2023-10-01 12:55:12')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_03.tif is done!', '2023-10-01 12:55:15')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_04.tif is done!', '2023-10-01 12:55:18')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_05.tif is done!', '2023-10-01 12:55:20')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_06.tif is done!', '2023-10-01 12:55:23')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_07.tif is done!', '2023-10-01 12:55:26')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_08.tif is done!', '2023-10-01 12:55:29')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_09.tif is done!', '2023-10-01 12:55:32')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_10.tif is done!', '2023-10-01 12:55:35')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_11.tif is done!', '2023-10-01 12:55:39')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1982_12.tif is done!', '2023-10-01 12:55:42')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_01.tif is done!', '2023-10-01 12:55:46')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_02.tif is done!', '2023-10-01 12:55:49')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_03.tif is done!', '2023-10-01 12:55:53')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_04.tif is done!', '2023-10-01 12:55:56')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_05.tif is done!', '2023-10-01 12:55:59')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_06.tif is done!', '2023-10-01 12:56:03')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_07.tif is done!', '2023-10-01 12:56:07')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_08.tif is done!', '2023-10-01 12:56:11')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_09.tif is done!', '2023-10-01 12:56:15')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_10.tif is done!', '2023-10-01 12:56:18')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_11.tif is done!', '2023-10-01 12:56:22')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1983_12.tif is done!', '2023-10-01 12:56:25')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_01.tif is done!', '2023-10-01 12:56:28')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_02.tif is done!', '2023-10-01 12:56:31')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_03.tif is done!', '2023-10-01 12:56:35')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_04.tif is done!', '2023-10-01 12:56:38')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_05.tif is done!', '2023-10-01 12:56:41')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_06.tif is done!', '2023-10-01 12:56:45')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_07.tif is done!', '2023-10-01 12:56:48')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_08.tif is done!', '2023-10-01 12:56:51')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_09.tif is done!', '2023-10-01 12:56:55')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_10.tif is done!', '2023-10-01 12:56:58')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_1984_11.tif is done!', '2023-10-01 12:57:02')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI11\\month\\clmSPEI11_month_

# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2021_10.tif is done!', '2023-10-01 13:55:30')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2021_11.tif is done!', '2023-10-01 13:55:33')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2021_12.tif is done!', '2023-10-01 13:55:37')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_01.tif is done!', '2023-10-01 13:55:40')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_02.tif is done!', '2023-10-01 13:55:43')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_03.tif is done!', '2023-10-01 13:55:46')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_04.tif is done!', '2023-10-01 13:55:49')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_05.tif is done!', '2023-10-01 13:55:52')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_06.tif is done!', '2023-10-01 13:55:56')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_07.tif is done!', '2023-10-01 13:56:00')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_08.tif is done!', '2023-10-01 13:56:04')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_09.tif is done!', '2023-10-01 13:56:07')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_10.tif is done!', '2023-10-01 13:56:10')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_11.tif is done!', '2023-10-01 13:56:14')
# ('E:\\drought\\step01_XY\\1km\\clmSPEI\\clmSPEI12\\month\\clmSPEI12_month_2022_12.tif is done!', '2023-10-01 13:56:17')
# ('work is done!', '2023-10-01 13:56:17')

# %%
print('SPEI站点趋势变化 格点化')
startyear,endyear=1982,2021
season_ID=['S1','S2','S3','S4','GS','Y']
print('IDW',datetime0.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
gridpath,cellSize='8km',  0.083333333
gridpath,cellSize='5km',  0.05
gridpath,cellSize='1km',  0.01

for dataname in ['SPEI','clmSPEI']:
    if dataname=='SPEI':speipath='SPEI_PM'#彭曼公式
    if dataname=='clmSPEI':speipath='SPEI_TH'#

    trend_Shp_Path=os.path.join(workpath,'data','SPEI','SPEI',speipath,'trend_shp')

    Trend_grid_Path=os.path.join(workpath,'step02_trend',gridpath,dataname)
    if not os.path.exists(Trend_grid_Path):  os.makedirs(Trend_grid_Path)

    shpfn=os.path.join(trend_Shp_Path,
                       dataname+'_trend_'+str(startyear)+'_'+str(endyear+1)+'.shp')

    for sel_s in ['S1','S2','S3','S4','GS','Y']:
        for s2 in ['mean','slope','p']:
            zField=sel_s+'_'+s2

            out_rs = Idw(shpfn, zField, cellSize, 2,  RadiusVariable(60, 10))
            s1='_'+sel_s
            if s1=='_Y':s1=''
            outfn='_'.join(['Trend',dataname,'year',str(startyear),str(endyear)+s1,s2])+'.tif'
            if s2=='mean':outfn='_'.join(['Mean',dataname,'year',str(startyear),str(endyear)+s1])+'.tif'
            outfn=os.path.join(Trend_grid_Path,outfn)
            out_rs.save(outfn)
            print(outfn)

print('it is ok',datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# SPEI站点趋势变化 格点化
# ('IDW', '2023-10-01 17:29:52')
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021_S1.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S1_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S1_p.tif
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021_S2.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S2_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S2_p.tif
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021_S3.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S3_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S3_p.tif
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021_S4.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S4_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_S4_p.tif
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021_GS.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_GS_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_GS_p.tif
# E:\drought\step02_trend\1km\SPEI\Mean_SPEI_year_1982_2021.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_slope.tif
# E:\drought\step02_trend\1km\SPEI\Trend_SPEI_year_1982_2021_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021_S1.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S1_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S1_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021_S2.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S2_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S2_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021_S3.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S3_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S3_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021_S4.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S4_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_S4_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021_GS.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_GS_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_GS_p.tif
# E:\drought\step02_trend\1km\clmSPEI\Mean_clmSPEI_year_1982_2021.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_slope.tif
# E:\drought\step02_trend\1km\clmSPEI\Trend_clmSPEI_year_1982_2021_p.tif
# ('it is ok', '2023-10-01 17:31:31')
